# %% [markdown]
# # SQL + Python for Data Analysis
# ### 📁 Project: Food Delivery Analysis
#
# ---
#
# ## ✅ 7.1 – Connect to SQLite Database
# - Import libraries
# - Load CSV file
# - Create SQLite DB + table
#
# ---
#
# ## ✅ 7.2 – Querying with SQL + Pandas
# - `SELECT *`
# - Filtering (`WHERE`)
# - Sorting (`ORDER BY`)
# - Aggregation (`GROUP BY`, `AVG`, `COUNT`, …)
#
# ---
#
# ## ✅ 7.3 – Visualization with Matplotlib / Seaborn
# - Plot ratings vs cost
# - Distribution of cuisines
# - Restaurants with highest ratings
#
# ---
#
# ## 📌 Dataset Info:
# - Source: Simulated Zomato-like data
# - Format: CSV
# - Columns: `restaurant_id`, `name`, `city`, `cuisine`, `average_cost`, `rating`, `delivery`
#
#
#
# ---

# %%
# Import Libraries
import pandas as pd
import sqlite3

# %%
# Load CSV file
df = pd.read_csv('food_delivery_data_large.csv')
df
# Out:
#    restaurant_id                           name       city   cuisine  \
# 0             R1                    Jenkins PLC       Pune  Lebanese
# 1             R2                     Austin Ltd     Mumbai  Lebanese
# 2             R3          Stone, Davis and Dunn    Kolkata      Thai
# 3             R4                Bennett-Herring  Hyderabad      Thai
# 4             R5       Miller, Flores and James       Pune    Indian
# 5             R6                   Pittman-Reed    Chennai    Indian
# 6             R7                    Perez Group    Chennai  Japanese
# 7             R8                       Cook Inc     Mumbai   Italian
# 8             R9                     Torres LLC      Delhi   Italian
# 9            R10                Boone-Hernandez     Mumbai  Japanese
# 10           R11                  Murphy-Butler  Hyderabad    Indian
# 11           R12     Wells, Potter and Chandler     Mumbai    Indian
# 12           R13           Thomas, Lee and King    Kolkata   Mexican
# ...

# %%
# Create SQLite DB + table
conn = sqlite3.connect('food_delivery.db')
df.to_sql('restaurants',conn,if_exists='replace',index=False)
# Out:
# 50

# %% [markdown]
# Querying with SQL + Pandas

# %%
# select
pd.read_sql_query('select * from restaurants',conn)
# Out:
#    restaurant_id                           name       city   cuisine  \
# 0             R1                    Jenkins PLC       Pune  Lebanese
# 1             R2                     Austin Ltd     Mumbai  Lebanese
# 2             R3          Stone, Davis and Dunn    Kolkata      Thai
# 3             R4                Bennett-Herring  Hyderabad      Thai
# 4             R5       Miller, Flores and James       Pune    Indian
# 5             R6                   Pittman-Reed    Chennai    Indian
# 6             R7                    Perez Group    Chennai  Japanese
# 7             R8                       Cook Inc     Mumbai   Italian
# 8             R9                     Torres LLC      Delhi   Italian
# 9            R10                Boone-Hernandez     Mumbai  Japanese
# 10           R11                  Murphy-Butler  Hyderabad    Indian
# 11           R12     Wells, Potter and Chandler     Mumbai    Indian
# 12           R13           Thomas, Lee and King    Kolkata   Mexican
# ...

# %% [markdown]
# #  Filtering with WHERE

# %%
# Display only restaurants that serve "Indian" cuisine:
query = "select * from restaurants where cuisine = 'Indian';"
df_indian = pd.read_sql_query(query, conn)
df_indian.head()
# Out:
#   restaurant_id                        name       city cuisine  average_cost  \
# 0            R5    Miller, Flores and James       Pune  Indian           583
# 1            R6                Pittman-Reed    Chennai  Indian          1107
# 2           R11               Murphy-Butler  Hyderabad  Indian          1143
# 3           R12  Wells, Potter and Chandler     Mumbai  Indian           231
# 4           R15                 Oconnor Inc    Kolkata  Indian           434
#
#    rating delivery
# 0     4.1      Yes
# 1     4.1      Yes
# 2     4.4      Yes
# 3     4.2       No
# 4     4.3      Yes

# %%
# Restaurants with a rating higher than 4.5:
query = "select name, city, rating from restaurants where rating > 4.5;"
df_top_rated = pd.read_sql_query(query, conn)
df_top_rated
# Out:
#                             name       city  rating
# 0                Boone-Hernandez     Mumbai     4.7
# 1                 Murray-Wheeler  Bangalore     4.8
# 2                       Shaw Inc       Pune     4.6
# 3  Clark, Mitchell and Valentine       Pune     5.0
# 4      Wilson, Keller and Newton     Mumbai     4.6
# 5                      Silva LLC  Bangalore     4.8
# 6                 Manning-Jordan     Mumbai     4.7
# 7               Patterson-Cherry      Delhi     5.0
# 8                       Vang Inc  Hyderabad     4.6

# %% [markdown]
# #  Sorting with ORDER BY

# %%
# Sort restaurants by rating in descending order:
query = "select name, rating from restaurants order by rating desc;"
df_sorted_rating = pd.read_sql_query(query, conn)
df_sorted_rating.head()
# Out:
#                             name  rating
# 0  Clark, Mitchell and Valentine     5.0
# 1               Patterson-Cherry     5.0
# 2                 Murray-Wheeler     4.8
# 3                      Silva LLC     4.8
# 4                Boone-Hernandez     4.7

# %%
# Sort by city in ascending order, and within each city, rating in descending order:
query = """
select name, city, rating
from restaurants
order by city asc, rating desc;
"""
df_sorted_city_rating = pd.read_sql_query(query, conn)
df_sorted_city_rating.head()
# Out:
#                         name       city  rating
# 0             Murray-Wheeler  Bangalore     4.8
# 1                  Silva LLC  Bangalore     4.8
# 2  Burke, Edwards and Harvey  Bangalore     4.4
# 3               Pittman-Reed    Chennai     4.1
# 4                Perez Group    Chennai     3.9

# %% [markdown]
# # Aggregation: avg, count

# %%
query="select city, avg(average_cost) as avg_cost from restaurants group by city"
pd.read_sql_query(query,conn)
# Out:
#         city    avg_cost
# 0  Bangalore  570.666667
# 1    Chennai  880.400000
# 2      Delhi  737.250000
# 3  Hyderabad  685.800000
# 4    Kolkata  772.000000
# 5     Mumbai  662.500000
# 6       Pune  660.600000

# %% [markdown]
# # Visualization with Matplotlib / Seaborn

# %% [markdown]
# # Plot ratings vs cost

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt


# Plot ratings vs cost
sns.scatterplot(data=df, x="average_cost", y="rating", hue="city")
plt.title("Rating vs Average Cost")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution of cuisines

# %%
# Cuisine distribution
sns.countplot(data=df, x="cuisine")
plt.xticks(rotation=45)
plt.title("Cuisine Distribution")
plt.show()

# %% [markdown]
# #  Visualization: Top Rated Restaurants

# %%
query = """
select name, city, rating
from restaurants
order by rating desc
limit 10;
"""
top_rated = pd.read_sql_query(query, conn)
top_rated
# Out:
#                             name       city  rating
# 0  Clark, Mitchell and Valentine       Pune     5.0
# 1               Patterson-Cherry      Delhi     5.0
# 2                 Murray-Wheeler  Bangalore     4.8
# 3                      Silva LLC  Bangalore     4.8
# 4                Boone-Hernandez     Mumbai     4.7
# 5                 Manning-Jordan     Mumbai     4.7
# 6                       Shaw Inc       Pune     4.6
# 7      Wilson, Keller and Newton     Mumbai     4.6
# 8                       Vang Inc  Hyderabad     4.6
# 9         Welch, Love and Porter      Delhi     4.5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.barplot(data=top_rated, x="rating", y="name", hue="city", dodge=False)
plt.title("Top 10 Highest Rated Restaurants")
plt.xlabel("Rating")
plt.ylabel("Restaurant Name")
plt.legend(title="City", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
